# %%
import nekt

nekt.data_access_token = "SEU_TOKEN_AQUI"

# %%
spark = nekt.get_spark_session()

df = nekt.load_table(layer_name="LAYER", table_name="TABLE")
df.createOrReplaceTempView("VIEW_NAME")
